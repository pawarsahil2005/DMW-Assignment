# %%
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("/home/pccoe/Desktop/228/Indian_Kids_Screen_Time (1).csv")
df
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                       NaN     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73            NaN
# 3      15  Female                       NaN         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26            NaN
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %%
df.head()
# Out:
#    Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0   14    Male                       NaN     Smartphone
# 1   11  Female                      4.61         Laptop
# 2   18  Female                      3.73            NaN
# 3   15  Female                       NaN         Laptop
# 4   12  Female                      5.89     Smartphone
#
#    Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                        True                               0.42
# 1                        True                               0.30
# 2                        True                               0.32
# 3                       False                                NaN
# 4                        True                               0.49
#
#            Health_Impacts Urban_or_Rural
# 0  Poor Sleep, Eye Strain          Urban
# 1              Poor Sleep          Urban
# 2              Poor Sleep          Urban
# 3                     NaN          Urban
# ...

# %%
df.shape
# Out:
# (9712, 8)

# %%
df.tail()
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 9707   17    Male                      3.26            NaN
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 9707                        True                               0.44
# 9708                        True                               0.40
# 9709                        True                               0.39
# 9710                        True                               0.43
# 9711                        True                               0.33
#
#                        Health_Impacts Urban_or_Rural
# 9707                       Poor Sleep          Urban
# 9708                       Poor Sleep          Rural
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9712 entries, 0 to 9711
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                9712 non-null   int64
#  1   Gender                             9712 non-null   object
#  2   Avg_Daily_Screen_Time_hr           8741 non-null   float64
#  3   Primary_Device                     8741 non-null   object
#  4   Exceeded_Recommended_Limit         9712 non-null   bool
#  5   Educational_to_Recreational_Ratio  8935 non-null   float64
#  6   Health_Impacts                     6170 non-null   object
#  7   Urban_or_Rural                     9712 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(4)
# memory usage: 540.7+ KB

# %%
8, 8df.describe()
# Out:
#                Age  Avg_Daily_Screen_Time_hr  \
# count  9712.000000               8741.000000
# mean     12.979201                  4.348766
# std       3.162437                  1.720755
# min       8.000000                  0.000000
# 25%      10.000000                  3.410000
# 50%      13.000000                  4.430000
# 75%      16.000000                  5.370000
# max      18.000000                 13.890000
#
#        Educational_to_Recreational_Ratio
# count                        8935.000000
# mean                            0.427287
# std                             0.073267
# min                             0.300000
# 25%                             0.370000
# 50%                             0.430000
# 75%                             0.480000
# max                             0.600000

# %%
df.dtypes
# Out:
# Age                                    int64
# Gender                                object
# Avg_Daily_Screen_Time_hr             float64
# Primary_Device                        object
# Exceeded_Recommended_Limit              bool
# Educational_to_Recreational_Ratio    float64
# Health_Impacts                        object
# Urban_or_Rural                        object
# dtype: object

# %%
df1 = df.copy()

# %% [markdown]
# ### Removing Duplicates

# %%
df1.duplicated().sum()
# Out:
# 58

# %%
df1 = df1.drop_duplicates()

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.shape
# Out:
# (9654, 8)

# %%
print("\nDataFrame after removing duplicates:\n", df1)
# Out:
# DataFrame after removing duplicates:
#        Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                       NaN     Smartphone
# 1      11  Female                      4.61         Laptop
# 2      18  Female                      3.73            NaN
# 3      15  Female                       NaN         Laptop
# 4      12  Female                      5.89     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                      3.26            NaN
# 9708   17  Female                      4.43     Smartphone
# 9709   16    Male                      5.62     Smartphone
# 9710   17    Male                      5.60             TV
# 9711   15  Female                      6.12             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %% [markdown]
# ### Removing the Missing Values

# %%
df1.dtypes
# Out:
# Age                                    int64
# Gender                                object
# Avg_Daily_Screen_Time_hr             float64
# Primary_Device                        object
# Exceeded_Recommended_Limit              bool
# Educational_to_Recreational_Ratio    float64
# Health_Impacts                        object
# Urban_or_Rural                        object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Age                                     0
# Gender                                  0
# Avg_Daily_Screen_Time_hr              971
# Primary_Device                        971
# Exceeded_Recommended_Limit              0
# Educational_to_Recreational_Ratio     777
# Health_Impacts                       3542
# Urban_or_Rural                          0
# dtype: int64

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.impute import SimpleImputer

# %%
print(df1['Avg_Daily_Screen_Time_hr'].mean())
print(df1['Avg_Daily_Screen_Time_hr'].median())
print(df1['Avg_Daily_Screen_Time_hr'].mode()[0])
# Out:
# 4.364102711397059
# 4.44
# 0.0

# %%
# Numerical Values scikit mean
num_imputer = SimpleImputer(strategy="mean")
df1['Avg_Daily_Screen_Time_hr'] = num_imputer.fit_transform(df1[['Avg_Daily_Screen_Time_hr']])

# %%
df1.isnull().sum()
# Out:
# Age                                     0
# Gender                                  0
# Avg_Daily_Screen_Time_hr                0
# Primary_Device                        969
# Exceeded_Recommended_Limit              0
# Educational_to_Recreational_Ratio     768
# Health_Impacts                       3495
# Urban_or_Rural                          0
# dtype: int64

# %%
print(df1['Educational_to_Recreational_Ratio'].mean())
print(df1['Educational_to_Recreational_Ratio'].median())
print(df1['Educational_to_Recreational_Ratio'].mode()[0])
# Out:
# 0.42709430564933604
# 0.43
# 0.45

# %%
num_imputer = SimpleImputer(strategy="median")
df1['Educational_to_Recreational_Ratio'] = num_imputer.fit_transform(df1[['Educational_to_Recreational_Ratio']])

# %%
df1.isnull().sum()
# Out:
# Age                                     0
# Gender                                  0
# Avg_Daily_Screen_Time_hr                0
# Primary_Device                        969
# Exceeded_Recommended_Limit              0
# Educational_to_Recreational_Ratio       0
# Health_Impacts                       3495
# Urban_or_Rural                          0
# dtype: int64

# %%
# For Categorical columns
print(df1['Primary_Device'].mode()[0])
# Out:
# Smartphone

# %%
df1['Primary_Device'] = df1['Primary_Device'].fillna(df1['Primary_Device'].mode()[0])

# %%
df1.isnull().sum()
# Out:
# Age                                     0
# Gender                                  0
# Avg_Daily_Screen_Time_hr                0
# Primary_Device                          0
# Exceeded_Recommended_Limit              0
# Educational_to_Recreational_Ratio       0
# Health_Impacts                       3495
# Urban_or_Rural                          0
# dtype: int64

# %%
print(df1['Health_Impacts'].mode()[0])
# Out:
# Poor Sleep

# %%
df1['Health_Impacts'] = df1['Health_Impacts'].fillna(df1['Health_Impacts'].mode()[0])

# %%
df1.isnull().sum()
# Out:
# Age                                  0
# Gender                               0
# Avg_Daily_Screen_Time_hr             0
# Primary_Device                       0
# Exceeded_Recommended_Limit           0
# Educational_to_Recreational_Ratio    0
# Health_Impacts                       0
# Urban_or_Rural                       0
# dtype: int64

# %% [markdown]
# ### Graphical Representation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 6))
sns.lineplot(data=df1, x='Age', y='Avg_Daily_Screen_Time_hr', marker='o')
plt.title("Average Daily Screen Time by Age")
plt.xlabel("Age")
plt.ylabel("Avg Daily Screen Time (hr)")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.barplot(data=df1, x='Age', y='Educational_to_Recreational_8, 8Ratio', palette='viridis')
plt.title("Educational to Recreational Screen Time Ratio by Age")
plt.xlabel("Age")
plt.ylabel("Edu/Recreation Ratio")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df1['Avg_Daily_Screen_Time_hr'], kde=True, bins=10)
plt.title("Distribution of Daily Screen Time")
plt.xlabel("Avg Daily Screen Time (hr)")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.boxplot(y=df1['Avg_Daily_Screen_Time_hr'])
plt.title("Box Plot of Avg Daily Screen Time")
plt.ylabel("Avg Daily Screen Time (hr)")
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.boxplot(y=df1['Age'])
plt.title("Box Plot of Age")
plt.ylabel("Age")
plt.show()

# %%
plt.figure(figsize=(6 ,6))
sns.boxplot(y=df1['Educational_to_Recreational_Ratio'])
plt.title("Box Plot of Educational_to_Recreational_Ratio")
plt.ylabel("Educational_to_Recreational_Ratio")
plt.show()

# %%
df1.hist(bins=30, figsize=(12, 8), color='orange', edgecolor='black')
plt.suptitle("Histograms of Numerical Columns", fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Pair Plot
sns.pairplot(df1,hue="Gender",palette="husl")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Removing Outliers

# %%
df1.describe()
# Out:
#                Age  Avg_Daily_Screen_Time_hr  \
# count  9654.000000               9654.000000
# mean     12.993889                  4.364103
# std       3.158551                  1.619101
# min       8.000000                  0.000000
# 25%      10.000000                  3.560000
# 50%      13.000000                  4.364103
# 75%      16.000000                  5.250000
# max      18.000000                 13.890000
#
#        Educational_to_Recreational_Ratio
# count                        9654.000000
# mean                            0.427325
# std                             0.070257
# min                             0.300000
# 25%                             0.370000
# 50%                             0.430000
# 75%                             0.470000
# max                             0.600000

# %%
Q1 = df1['Age'].quantile(0.25)
Q3 = df1['Age'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
# print outlier
outliers = df1[(df1['Age'] < lower_bound) | (df1['Age'] > upper_bound)]
print(outliers)
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Avg_Daily_Screen_Time_hr, Primary_Device, Exceeded_Recommended_Limit, Educational_to_Recreational_Ratio, Health_Impacts, Urban_or_Rural]
# Index: []

# %%
Q1 = df1['Avg_Daily_Screen_Time_hr'].quantile(0.25)
Q3 = df1['Avg_Daily_Screen_Time_hr'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
# print outlier
outliers = df1[(df1['Avg_Daily_Screen_Time_hr'] < lower_bound) | (df1['Avg_Daily_Screen_Time_hr'] > upper_bound)]
outliers
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 28      8    Male                      0.31     Smartphone
# 46      9  Female                      0.00     Smartphone
# 58      9    Male                      0.00     Smartphone
# 69      9    Male                      0.90         Tablet
# 92     10  Female                      0.00         Tablet
# ...   ...     ...                       ...            ...
# 9630    8    Male                      9.70         Tablet
# 9656    8  Female                      0.73             TV
# 9659    8    Male                      0.00             TV
# 9660    9  Female                      0.00             TV
# 9667    8  Female                      0.89         Tablet
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 28                         False                               0.51
# 46                         False                               0.47
# ...

# %%
df1.shape
# Out:
# (9654, 8)

# %%
# After removing outliers
df2 = df1[(df1['Avg_Daily_Screen_Time_hr'] >= lower_bound) & (df1['Avg_Daily_Screen_Time_hr'] <= upper_bound)]
df2
# Out:
#       Age  Gender  Avg_Daily_Screen_Time_hr Primary_Device  \
# 0      14    Male                  4.364103     Smartphone
# 1      11  Female                  4.610000         Laptop
# 2      18  Female                  3.730000     Smartphone
# 3      15  Female                  4.364103         Laptop
# 4      12  Female                  5.890000     Smartphone
# ...   ...     ...                       ...            ...
# 9707   17    Male                  3.260000     Smartphone
# 9708   17  Female                  4.430000     Smartphone
# 9709   16    Male                  5.620000     Smartphone
# 9710   17    Male                  5.600000             TV
# 9711   15  Female                  6.120000             TV
#
#       Exceeded_Recommended_Limit  Educational_to_Recreational_Ratio  \
# 0                           True                               0.42
# 1                           True                               0.30
# ...

# %%
df2.shape
# Out:
# (9079, 8)

# %%
Q1 = df2['Educational_to_Recreational_Ratio'].quantile(0.25)
Q3 = df2['Educational_to_Recreational_Ratio'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
# print outlier
outliers = df2[(df2['Educational_to_Recreational_Ratio'] < lower_bound) | (df2['Educational_to_Recreational_Ratio'] > upper_bound)]
outliers
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Avg_Daily_Screen_Time_hr, Primary_Device, Exceeded_Recommended_Limit, Educational_to_Recreational_Ratio, Health_Impacts, Urban_or_Rural]
# Index: []

# %%
df2.describe()
# Out:
#                Age  Avg_Daily_Screen_Time_hr  \
# count  9079.000000               9079.000000
# mean     13.228439                  4.439631
# std       3.086550                  1.270025
# min       8.000000                  1.030000
# 25%      11.000000                  3.670000
# 50%      13.000000                  4.364103
# 75%      16.000000                  5.220000
# max      18.000000                  7.780000
#
#        Educational_to_Recreational_Ratio
# count                        9079.000000
# mean                            0.423372
# std                             0.068737
# min                             0.300000
# 25%                             0.370000
# 50%                             0.430000
# 75%                             0.470000
# max                             0.600000

# %%
df2.isnull().sum()
# Out:
# Age                                  0
# Gender                               0
# Avg_Daily_Screen_Time_hr             0
# Primary_Device                       0
# Exceeded_Recommended_Limit           0
# Educational_to_Recreational_Ratio    0
# Health_Impacts                       0
# Urban_or_Rural                       0
# dtype: int64

# %%
# After Removing Outliers
plt.figure(figsize=(6, 6))
sns.boxplot(y=df2['Avg_Daily_Screen_Time_hr'])
plt.title("Box Plot of Avg Daily Screen Time")
plt.ylabel("Avg Daily Screen Time (hr)")
plt.show()

# %% [markdown]
# ### Standardization & Normalization

# %%
df3 = df2.copy()

# %%
numeric_cols = df3.select_dtypes(include='number').columns
numeric_cols
# Out:
# Index(['Age', 'Avg_Daily_Screen_Time_hr', 'Educational_to_Recreational_Ratio'], dtype='object')

# %% [markdown]
# #### Min-Max Scaler

# %%
from sklearn.preprocessing import MinMaxScaler

minmax_scaled = MinMaxScaler().fit_transform(df3[numeric_cols])
pd.DataFrame(minmax_scaled, columns=numeric_cols).head()
# Out:
#    Age  Avg_Daily_Screen_Time_hr  Educational_to_Recreational_Ratio
# 0  0.6                  0.493941                           0.400000
# 1  0.3                  0.530370                           0.000000
# 2  1.0                  0.400000                           0.066667
# 3  0.7                  0.493941                           0.433333
# 4  0.4                  0.720000                           0.633333

# %% [markdown]
# #### Robust Scaler

# %%
from sklearn.preprocessing import RobustScaler

robust_scaled = RobustScaler().fit_transform(df3[numeric_cols])
pd.DataFrame(robust_scaled, columns=numeric_cols).head()
# Out:
#    Age  Avg_Daily_Screen_Time_hr  Educational_to_Recreational_Ratio
# 0  0.2                  0.000000                               -0.1
# 1 -0.4                  0.158643                               -1.3
# 2  1.0                 -0.409099                               -1.1
# 3  0.4                  0.000000                                0.0
# 4 -0.2                  0.984450                                0.6

# %% [markdown]
# #### Standard Scaler and z-score normalization

# %%
from sklearn.preprocessing import StandardScaler

standard_scaled = StandardScaler().fit_transform(df3[numeric_cols])
pd.DataFrame(standard_scaled, columns=numeric_cols).head()
# Out:
#         Age  Avg_Daily_Screen_Time_hr  Educational_to_Recreational_Ratio
# 0  0.249989                 -0.059473                          -0.049053
# 1 -0.722024                  0.134154                          -1.794946
# 2  1.546006                 -0.558784                          -1.503964
# 3  0.573993                 -0.059473                           0.096439
# 4 -0.398019                  1.142063                           0.969385

# %% [markdown]
# ### Central Tendency & Dispersion

# %%
numeric_df = df3.select_dtypes(include=['number'])

# Central Tendency 
mean_values = numeric_df.mean()
median_values = numeric_df.median()
mode_values = numeric_df.mode().iloc[0]

print("\nMean:\n", mean_values)
print("\nMedian:\n", median_values)
print("\nMode:\n", mode_values)
# Out:
# Mean:
#  Age                                  13.228439
# Avg_Daily_Screen_Time_hr              4.439631
# Educational_to_Recreational_Ratio     0.423372
# dtype: float64
#
# Median:
#  Age                                  13.000000
# Avg_Daily_Screen_Time_hr              4.364103
# Educational_to_Recreational_Ratio     0.430000
# dtype: float64
#
# Mode:
#  Age                                  17.000000
# Avg_Daily_Screen_Time_hr              4.364103
# Educational_to_Recreational_Ratio     0.430000
# Name: 0, dtype: float64

# %%
# Dispersion 
std_values = numeric_df.std()
var_values = numeric_df.var()
range_values = numeric_df.max() - numeric_df.min()

print("\nStandard Deviation:\n", std_values)
print("\nVariance:\n", var_values)
print("\nRange:\n", range_values)
# Out:
# Standard Deviation:
#  Age                                  3.086550
# Avg_Daily_Screen_Time_hr             1.270025
# Educational_to_Recreational_Ratio    0.068737
# dtype: float64
#
# Variance:
#  Age                                  9.526792
# Avg_Daily_Screen_Time_hr             1.612965
# Educational_to_Recreational_Ratio    0.004725
# dtype: float64
#
# Range:
#  Age                                  10.00
# Avg_Daily_Screen_Time_hr              6.75
# Educational_to_Recreational_Ratio     0.30
# dtype: float64
